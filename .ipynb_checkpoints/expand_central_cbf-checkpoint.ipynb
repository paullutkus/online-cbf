# %%
import numpy as np
from data import generate_radial_mesh, generate_rectangle, insert_shape, plot_data, plot_shape_data
from agent import Agent

# %load_ext autoreload
# %autoreload 2
# Out:
# No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)

# %%
'''
inner, boundary = generate_radial_mesh(radius=0.8, density=33, boundary_pct=0.25)
temp_grid = np.vstack((inner[0], boundary[0]))
temp_obs_dict = {tuple(x) : 0 for x in inner[0]} | {tuple(x) : 1 for x in boundary[0]} 
plot_data(temp_grid, temp_obs_dict)
'''

grid, obs_dict = generate_rectangle(height=1, width=1, density=1e4, unsafe_margin=0.2, center=(0,0))
obs_dict = insert_shape(np.array([-0.33, 0]), grid, obs_dict, shape='circle', scale=0.15)
obs_dict = insert_shape(np.array([0.25, 0.16]), grid, obs_dict, shape='triangle', scale=0.3, theta=-np.pi/8)
obs_dict = insert_shape(np.array([0, 0.30]), grid, obs_dict, shape='rhombus', scale=0.10, theta=np.pi/6)
plot_shape_data(grid, obs_dict)

# %%
#agent = Agent((inner, boundary), verbose=False)
agent = Agent(grid, obs_dict, sensor_range=0.18, verbose=False)
# Out:
# position is [0 0]
# time is 0
# (983, 2)
# 491
# (738, 2)
# 369
# new position is [0 0]
# new time is 0
# using norm trick
# using norm trick
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 2
#       1 #agent = Agent((inner, boundary), verbose=False)
# ----> 2 agent = Agent(grid, obs_dict, sensor_range=0.18, verbose=False)
#
# File ~/Documents/cbf/learning-cbfs/central_cbf_expansion/agent.py:55, in Agent.__init__(self, data, obs_dict, params_and_bias, pos, t, sensor_range, verbose)
#      53     self.bias_param = []
#      54     self.scan(plot=True)
# ---> 55     self.train()
#      56 else:
#      57     self.params, self.bias_param = params_and_bias
#
# File ~/Documents/cbf/learning-cbfs/central_cbf_expansion/agent.py:123, in Agent.train(self, verbose)
#     121     verbose_local_scope = self.verbose
#     122 scan_data = (self.scan_constraint[0], self.scan_constraint[1], self.scan_filler[0], self.scan_filler[1], self.scan_unsafe[0], self.scan_unsafe[1])
# --> 123 params, bias_param = solve_model(scan_data,
#     124 gamma_xu_constraints=GAMMA*np.ones((self.scan_constraint[0].shape[0],)),
#     125 gamma_xu_fillers=GAMMA*np.ones((self.scan_filler[0].shape[0],)),
#     126 safe_values=SAFE_VALUE*np.ones((self.scan_constraint[0].shape[0],)),
#     127 unsafe_values=UNSAFE_VALUE*np.ones((self.scan_unsafe[0].shape[0],)),
#     128 verbose=verbose_local_scope, use_casadi=True, norm_trick=True)
#     129 self.params.append(params)
#     130 self.bias_param.append(bias_param)
#
# File ~/Documents/cbf/learning-cbfs/central_cbf_expansion/optim.py:96, in solve_model(data, gamma_xu_constraints, gamma_xu_fillers, safe_values, unsafe_values, verbose, use_bias, norm_trick, use_casadi)
#      94 if norm_trick:
#      95     print("using norm trick")
# ---> 96     phis = device_get(phi(x_filler, RF_WEIGHTS))
#      97     Dphixdots = device_get(
#      98             vmap(lambda x: jnp.dot(jacobian(phi, argnums=0)(x, RF_WEIGHTS), dynamics_f(x)),
#      99                 in_axes=0)(x_filler))
#     100     Dz = device_get(
#     101             vmap(lambda x: jacobian(phi, argnums=0)(x, RF_WEIGHTS) @ dynamics_g(x).T,
#     102                 in_axes=0)(x_filler))
#
# File ~/Documents/cbf/learning-cbfs/central_cbf_expansion/optim.py:28, in phi(X, rf_weights)
#      26 W, b = rf_weights
#      27 n_rf = len(b)
# ---> 28 return jnp.sqrt(2.0 / n_rf) * jnp.cos(X.dot(W) + b)
#
# ValueError: shapes (0,) and (2,8) not aligned: 0 (dim 0) != 2 (dim 0)

# %%
#%debug
for n in range(20):
    waypt = agent.get_waypoint(n_rays=100, eps=1e-3, scale=2)
    agent.traverse(t_end=5, info_mpc=True, mpc=False, track_control=False, steps=50, horizon=5, waypt=waypt)
    agent.scan(plot=True)
    agent.train(verbose=False)

# %%
for n in range(20):
    waypt = agent.get_waypoint(n_rays=100, eps=1e-4, scale=2)
    agent.traverse(t_end=5, info_mpc=True, mpc=False, track_control=False, steps=50, horizon=10, waypt=waypt)
    agent.scan(plot=True)
    agent.train(verbose=False)
