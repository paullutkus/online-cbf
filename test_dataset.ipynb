# %%
import numpy as np
from data import generate_rectangle, insert_shape, plot_shape_dataset
import matplotlib.pyplot as plt

# %load_ext autoreload
# %autoreload 2
# Out:
# No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)

# %%
grid, obs_dict = generate_rectangle(1, 1.5, density=5e3, unsafe_margin=0.15, center=(0,0))
obs_dict = insert_shape(np.array((0,0.25)), grid, obs_dict, shape='triangle', scale=0.2, theta=np.pi/8)
obs_dict = insert_shape(np.array((-0.45, -0.2))  , grid, obs_dict, shape='circle'  , scale=0.15, theta=0)
obs_dict = insert_shape(np.array((0.45, 0.35))  , grid, obs_dict, shape='circle'  , scale=0.1, theta=0)
obs_dict = insert_shape(np.array((0.25, -0.25))  , grid, obs_dict, shape='rhombus'  , scale=0.15, theta=-np.pi/8)
plot_shape_data(grid, obs_dict)
#print(obs_dict)
